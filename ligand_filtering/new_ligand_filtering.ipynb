# %%
import os
import shutil
import numpy as np
import re
from collections import defaultdict
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem, Draw
from rdkit.Chem.Draw import IPythonConsole, rdMolDraw2D
import filtering_functions as ff

# %% [markdown]
# ### Mark Ligands To Remove

# %%
# filters we utilized to remove ligands from the library 
df = pd.read_excel('sample_SMILES.xlsx')
df = ff.molecular_weight_filter(df)
df = ff.forbidden_substructures_filter(df)
df = ff.multiple_binding_sites_filter(df)
df = ff.missing_bind_site_filter(df)
df = ff.heterocycle_filter(df)
df = ff.isotopes_filter(df)
df = ff.other_metals_filter(df)
display (df)
# Out:
# 1 ligands over molecular weight limit were marked for removal.
# 0 ligands had forbidden substructures and were marked for removal.
# 0 ligands had multiple binding sites and were marked for removal.
# 1 ligands are missing a binding site and were marked for removal.
# 0 ligands contained problematic nitrogen heterocycles and were marked for removal.
# 0 ligands were duplicates due to isotope encoding and were marked for removal.
# 0 ligands contained metals and were marked for removal.
#                   id                                             SMILES  \
# 0    Lig_biox_sample                    C[C@H]1COC(C2=N[C@@H](C)CO2)=N1
# 1    Lig_pyox_sample                    CC(C)(C)[C@H]1COC(c2ncccc2F)=N1
# 2    Lig_biim_sample  CC([C@H]1CN(C2=CC=CC(C(C)(C)C)=C2)C(C3=N[C@@H]...
# 3     Lig_box_sample  CC(C)(C)[C@H]1COC(C2(C3=N[C@@H](C(C)(C)C)CO3)C...
# 4     Lig_bpy_sample         CC(C1=CC=NC(C2=NC=CC(C(C)(C)C)=C2)=C1)(C)C
# ...
