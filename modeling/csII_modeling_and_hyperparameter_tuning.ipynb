# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import rcParams
from matplotlib import lines as mlines
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold
from sklearn.kernel_ridge import KernelRidge
from sklearn.metrics import mean_absolute_error
from sklearn.feature_selection import SelectKBest, f_regression, mutual_info_regression

from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor

from sklearn.kernel_ridge import KernelRidge

import helpers as hp

# %% [markdown]
# ### Pre-Process Modeling Data

# %%
#data with properties and DDG data
df = pd.read_excel('fluoride_modeling_properties_w_experimental_data.xlsx',
                   sheet_name='CS2_combined_ddg', header=1)

df_train = df[df['set'] == 'train']
df_internal_test = df[df['set'] == 'validation']
df_external_test = df[df['set'] == 'test']

# train
df_exp_train = df_train.loc[:,:'ligand_class']
df_features_train = df_train.loc[:,'HOMO_Boltz':]

# validation
df_exp_internal_test = df_internal_test.loc[:,:'ligand_class']
df_features_internal_test = df_internal_test.loc[:,'HOMO_Boltz':]

# test
df_exp_external_test = df_external_test.loc[:,:'ligand_class']
df_features_external_test = df_external_test.loc[:,'HOMO_Boltz':]

# %% [markdown]
# #### Remove Collinear Features

# %% [markdown]
# This is an optional step that was evaluated for model performance but not used to produce the final model

# %%
threshold = 0.7

# remove collinear features 
print(f'Shape of descriptors file before removing parameters with R^2 > {threshold} :',df_features_train.shape)
df_corr = df_features_train.corr()
df_not_correlated = ~(df_corr.mask(np.tril(np.ones([len(df_corr)]*2, dtype=bool))).abs() > threshold).any()
un_corr_idx = df_not_correlated.loc[df_not_correlated[df_not_correlated.index] == True].index
df_features_train = df_features_train[un_corr_idx]
df_features_internal_test = df_features_internal_test[un_corr_idx]
df_features_external_test = df_features_external_test[un_corr_idx]
print(f'Shape of descriptors file after removing parameters with R^2 > {threshold} : ',df_features_train.shape)
# Out:
# Shape of descriptors file before removing parameters with R^2 > 0.7 : (32, 521)
# Shape of descriptors file after removing parameters with R^2 > 0.7 :  (32, 20)

# %% [markdown]
# #### Scale Modeling Data

# %% [markdown]
# all features were scaled using the standard scaler for all modeling efforts

# %%
scaler = StandardScaler()
df_features_train_scaled = pd.DataFrame(scaler.fit_transform(df_features_train), columns=df_features_train.columns)
df_features_internal_test_scaled = pd.DataFrame(scaler.transform(df_features_internal_test), columns=df_features_internal_test.columns)
df_features_external_test_scaled = pd.DataFrame(scaler.transform(df_features_external_test), columns=df_features_external_test.columns)

train_scaled = pd.concat([df_exp_train.reset_index(drop=True), df_features_train_scaled.reset_index(drop=True)], axis=1)
internal_test_scaled = pd.concat([df_exp_internal_test.reset_index(drop=True), df_features_internal_test_scaled.reset_index(drop=True)], axis=1)
external_test_scaled = pd.concat([df_exp_external_test.reset_index(drop=True), df_features_external_test_scaled.reset_index(drop=True)], axis=1)

df_scaled = pd.concat([train_scaled, internal_test_scaled, external_test_scaled], axis=0).reset_index(drop=True)

# %% [markdown]
# #### Final processing for modeling

# %%
X_train = df_features_train_scaled
y_train = (train_scaled['ddg_flipped'])
y_train_labels = train_scaled['ligandID']

X_internal_test = df_features_internal_test_scaled
y_internal_test = (internal_test_scaled['ddg_flipped'])
y_internal_test_labels = internal_test_scaled['ligandID']

X_external_test = df_features_external_test_scaled
y_external_test = (external_test_scaled['ddg_flipped'])
y_external_test_labels = external_test_scaled['ligandID']

# %% [markdown]
# ### KNN-R Modeling + Hyperparameter Tuning

# %% [markdown]
# #### Tune hyperparameters to find best model

# %%
best_df_r2, best_params_r2, best_features_r2, best_df_mae, best_params_mae, best_features_mae = hp.model_selection_knn(
    X_train, y_train, y_train_labels,
    X_internal_test, y_internal_test, y_internal_test_labels,
    scoring_list=[f_regression, mutual_info_regression],
    k_list=[2, 3, 4, 5], #limit to what is reasonable for this size dataset
    neighbors_list=[3, 5, 10])
# Out:
# Selected feature names: ['Sterimol_B1_Ni_N2(Å)_morfeus_low_E', '%Vbur_Ni_octant_–,–,–_Boltz']
#
# Testing: scoring=f_regression, k=2, n_neighbors=3
# knn train R2: 0.978, MAE: 0.053
# knn internal_test R2: 0.737, MAE: 0.318
# --> Internal R2: 0.737, MAE: 0.318
#
# Testing: scoring=f_regression, k=2, n_neighbors=5
# knn train R2: 0.978, MAE: 0.053
# knn internal_test R2: 0.760, MAE: 0.340
# --> Internal R2: 0.760, MAE: 0.340
#
# Testing: scoring=f_regression, k=2, n_neighbors=10
# knn train R2: 0.978, MAE: 0.053
# knn internal_test R2: 0.741, MAE: 0.384
# --> Internal R2: 0.741, MAE: 0.384
# Selected feature names: ['Sterimol_B1_N2_Ni(Å)_morfeus_low_E', 'Sterimol_B1_Ni_N2(Å)_morfeus_low_E', '%Vbur_Ni_octant_–,–,–_Boltz']
#
# Testing: scoring=f_regression, k=3, n_neighbors=3
# knn train R2: 0.978, MAE: 0.053
# knn internal_test R2: 0.670, MAE: 0.373
# --> Internal R2: 0.670, MAE: 0.373
#
# Testing: scoring=f_regression, k=3, n_neighbors=5
# knn train R2: 0.978, MAE: 0.053
# knn internal_test R2: 0.727, MAE: 0.355
# --> Internal R2: 0.727, MAE: 0.355
#
# Testing: scoring=f_regression, k=3, n_neighbors=10
# knn train R2: 0.978, MAE: 0.053
# knn internal_test R2: 0.896, MAE: 0.317
# --> Internal R2: 0.896, MAE: 0.317
# Selected feature names: ['Sterimol_B1_N2_Ni(Å)_morfeus_low_E', 'Sterimol_B1_Ni_N2(Å)_morfeus_low_E', 'Buried_Sterimol_B1_Ni_N2_5.0(Å)_low_E', '%Vbur_Ni_octant_–,–,–_Boltz']
#
# Testing: scoring=f_regression, k=4, n_neighbors=3
# knn train R2: 0.978, MAE: 0.053
# knn internal_test R2: 0.853, MAE: 0.266
# --> Internal R2: 0.853, MAE: 0.266
#
# Testing: scoring=f_regression, k=4, n_neighbors=5
# knn train R2: 0.978, MAE: 0.053
# knn internal_test R2: 0.863, MAE: 0.292
# --> Internal R2: 0.863, MAE: 0.292
#
# Testing: scoring=f_regression, k=4, n_neighbors=10
# knn train R2: 0.978, MAE: 0.053
# knn internal_test R2: 0.863, MAE: 0.309
# --> Internal R2: 0.863, MAE: 0.309
# Selected feature names: ['Sterimol_B1_N2_Ni(Å)_morfeus_low_E', 'Sterimol_B1_Ni_N2(Å)_morfeus_max', 'Sterimol_B1_Ni_N2(Å)_morfeus_low_E', 'Buried_Sterimol_B1_Ni_N2_5.0(Å)_low_E', '%Vbur_Ni_octant_–,–,–_Boltz']
#
# Testing: scoring=f_regression, k=5, n_neighbors=3
# knn train R2: 0.978, MAE: 0.053
# knn internal_test R2: 0.786, MAE: 0.363
# --> Internal R2: 0.786, MAE: 0.363
#
# Testing: scoring=f_regression, k=5, n_neighbors=5
# knn train R2: 0.978, MAE: 0.053
# knn internal_test R2: 0.851, MAE: 0.320
# --> Internal R2: 0.851, MAE: 0.320
#
# Testing: scoring=f_regression, k=5, n_neighbors=10
# knn train R2: 0.978, MAE: 0.053
# knn internal_test R2: 0.854, MAE: 0.310
# --> Internal R2: 0.854, MAE: 0.310
# Selected feature names: ['Buried_Sterimol_B5_N1_Ni_5.0(Å)_Boltz', 'Buried_Sterimol_B5_N1_Ni_5.0(Å)_low_E']
#
# Testing: scoring=mutual_info_regression, k=2, n_neighbors=3
# knn train R2: 0.978, MAE: 0.053
# knn internal_test R2: 0.218, MAE: 0.546
# --> Internal R2: 0.218, MAE: 0.546
#
# Testing: scoring=mutual_info_regression, k=2, n_neighbors=5
# knn train R2: 0.978, MAE: 0.053
# knn internal_test R2: 0.259, MAE: 0.533
# --> Internal R2: 0.259, MAE: 0.533
#
# Testing: scoring=mutual_info_regression, k=2, n_neighbors=10
# knn train R2: 0.978, MAE: 0.053
# knn internal_test R2: 0.258, MAE: 0.495
# --> Internal R2: 0.258, MAE: 0.495
# Selected feature names: ['%Vbur_N2_4.5Å_min', 'Buried_Sterimol_B5_N1_Ni_5.0(Å)_Boltz', 'Buried_Sterimol_B5_N1_Ni_5.0(Å)_low_E']
#
# Testing: scoring=mutual_info_regression, k=3, n_neighbors=3
# knn train R2: 0.978, MAE: 0.053
# knn internal_test R2: 0.863, MAE: 0.260
# --> Internal R2: 0.863, MAE: 0.260
#
# Testing: scoring=mutual_info_regression, k=3, n_neighbors=5
# knn train R2: 0.978, MAE: 0.053
# knn internal_test R2: 0.767, MAE: 0.316
# --> Internal R2: 0.767, MAE: 0.316
#
# Testing: scoring=mutual_info_regression, k=3, n_neighbors=10
# knn train R2: 0.978, MAE: 0.053
# knn internal_test R2: 0.701, MAE: 0.367
# --> Internal R2: 0.701, MAE: 0.367
# Selected feature names: ['%Vbur_C1_3.0Å_min', '%Vbur_N2_4.5Å_min', 'Buried_Sterimol_B5_N1_Ni_5.0(Å)_Boltz', 'Buried_Sterimol_B5_N1_Ni_5.0(Å)_low_E']
#
# Testing: scoring=mutual_info_regression, k=4, n_neighbors=3
# knn train R2: 0.978, MAE: 0.053
# knn internal_test R2: 0.632, MAE: 0.371
# --> Internal R2: 0.632, MAE: 0.371
#
# Testing: scoring=mutual_info_regression, k=4, n_neighbors=5
# knn train R2: 0.978, MAE: 0.053
# knn internal_test R2: 0.615, MAE: 0.363
# --> Internal R2: 0.615, MAE: 0.363
#
# Testing: scoring=mutual_info_regression, k=4, n_neighbors=10
# knn train R2: 0.978, MAE: 0.053
# knn internal_test R2: 0.740, MAE: 0.311
# --> Internal R2: 0.740, MAE: 0.311
# Selected feature names: ['%Vbur_Ni_2.0Å_Boltz', '%Vbur_C1_3.0Å_min', '%Vbur_N2_4.5Å_min', 'Buried_Sterimol_B5_N1_Ni_5.0(Å)_Boltz', 'Buried_Sterimol_B5_N1_Ni_5.0(Å)_low_E']
#
# Testing: scoring=mutual_info_regression, k=5, n_neighbors=3
# knn train R2: 0.978, MAE: 0.053
# knn internal_test R2: 0.596, MAE: 0.372
# --> Internal R2: 0.596, MAE: 0.372
#
# Testing: scoring=mutual_info_regression, k=5, n_neighbors=5
# knn train R2: 0.978, MAE: 0.053
# knn internal_test R2: 0.592, MAE: 0.378
# --> Internal R2: 0.592, MAE: 0.378
#
# Testing: scoring=mutual_info_regression, k=5, n_neighbors=10
# knn train R2: 0.978, MAE: 0.053
# knn internal_test R2: 0.675, MAE: 0.343
# --> Internal R2: 0.675, MAE: 0.343
#
#  Best Model by Internal Test R2
# {'scoring': 'f_regression', 'k': 3, 'n_neighbors': 10}
# R2: 0.896
# Selected Features: ['Sterimol_B1_N2_Ni(Å)_morfeus_low_E', 'Sterimol_B1_Ni_N2(Å)_morfeus_low_E', '%Vbur_Ni_octant_–,–,–_Boltz']
#
#  Best Model by Internal Test MAE
# {'scoring': 'mutual_info_regression', 'k': 3, 'n_neighbors': 3}
# MAE: 0.260
# Selected Features: ['%Vbur_N2_4.5Å_min', 'Buried_Sterimol_B5_N1_Ni_5.0(Å)_Boltz', 'Buried_Sterimol_B5_N1_Ni_5.0(Å)_low_E']

# %% [markdown]
# #### Look at one Model

# %%
# perform feature selection
X_train_selected, X_internal_test_selected, X_external_test_selected, selected_features = hp.feature_selection(
    selection_method='select_k_best', #choose selection method, here we used k best
    n_features=3, # choose number of features you want in model 
    X_train=X_train,
    y_train=y_train,
    scoring=f_regression,
    X_internal_test=X_internal_test,
    X_external_test=X_external_test
)
# Out:
# Selected feature names: ['Sterimol_B1_N2_Ni(Å)_morfeus_low_E', 'Sterimol_B1_Ni_N2(Å)_morfeus_low_E', '%Vbur_Ni_octant_–,–,–_Boltz']

# %%
# model and plot results using knn
knn_results = hp.regression('knn-r', X_train_selected, y_train, y_train_labels,
               n_neighbors=10, weights='distance', p=1,
               X_internal_test=X_internal_test_selected, y_internal_test=y_internal_test, 
               y_internal_test_labels=y_internal_test_labels,
               X_external_test=X_external_test_selected, y_external_test=y_external_test,
               y_external_test_labels=y_external_test_labels)

# plot results 
fig, ax = plt.subplots(figsize=(6, 6))
ax.set_xlabel('Experimental $ΔΔG^{‡}$', fontsize=16)
ax.set_ylabel('Predicted $ΔΔG^{‡}$ (kcal/mol)', fontsize=16)
subset_train = knn_results[knn_results['set'] == 'train']
ax.scatter(subset_train['true_value'], subset_train['predicted_value_knn'], color='black', label='Train', alpha=0.7)
subset_internal_test = knn_results[knn_results['set'] == 'internal_test']
ax.scatter(subset_internal_test['true_value'], subset_internal_test['predicted_value_knn'], color='blue', label='Internal Test', alpha=0.7)
subset_external_test = knn_results[knn_results['set'] == 'external_test']
ax.scatter(subset_external_test['true_value'], subset_external_test['predicted_value_knn'], color='green', label='External Test', alpha=0.7)
ax.legend()
# Out:
# knn train R2: 0.978, MAE: 0.053
# knn internal_test R2: 0.896, MAE: 0.317
# knn external_test R2: 0.342, MAE: 0.277

# %% [markdown]
# ### KRR + Hyperparameter Tuning

# %% [markdown]
# #### Tune hyperparameters to find best model

# %%
best_df_r2, best_params_r2, best_features_r2, best_df_mae, best_params_mae, best_features_mae =  hp.model_selection_krr(X_train, y_train, y_train_labels,
                        X_internal_test, y_internal_test, y_internal_test_labels,
                        ridge_alpha_list=[0.1, 0.3, 1.0],
                        krr_alpha_list=[0.7, 1.0, 2.0],
                        kernel_list=['linear', 'polynomial', 'rbf'],
                        n_features_list=[2, 3, 4, 5])
# Out:
# Selected feature names: ['η_max', 'Buried_Sterimol_B5_N1_Ni_5.0(Å)_min']
#
# Testing: ridge_alpha=0.1, krr_alpha=0.7, kernel=linear, n_features=2
# --> Internal R2: 0.711, MAE: 0.465
#
# Testing: ridge_alpha=0.1, krr_alpha=0.7, kernel=polynomial, n_features=2
# --> Internal R2: 0.763, MAE: 0.276
#
# Testing: ridge_alpha=0.1, krr_alpha=0.7, kernel=rbf, n_features=2
# --> Internal R2: 0.722, MAE: 0.323
#
# Testing: ridge_alpha=0.1, krr_alpha=1.0, kernel=linear, n_features=2
# --> Internal R2: 0.711, MAE: 0.464
#
# Testing: ridge_alpha=0.1, krr_alpha=1.0, kernel=polynomial, n_features=2
# --> Internal R2: 0.760, MAE: 0.279
#
# Testing: ridge_alpha=0.1, krr_alpha=1.0, kernel=rbf, n_features=2
# --> Internal R2: 0.723, MAE: 0.336
#
# Testing: ridge_alpha=0.1, krr_alpha=2.0, kernel=linear, n_features=2
# --> Internal R2: 0.713, MAE: 0.459
#
# Testing: ridge_alpha=0.1, krr_alpha=2.0, kernel=polynomial, n_features=2
# --> Internal R2: 0.755, MAE: 0.285
#
# Testing: ridge_alpha=0.1, krr_alpha=2.0, kernel=rbf, n_features=2
# --> Internal R2: 0.729, MAE: 0.364
# Selected feature names: ['η_max', 'Buried_Sterimol_B5_N1_Ni_5.0(Å)_min', '%Vbur_Ni_octant_–,–,–_Boltz']
#
# Testing: ridge_alpha=0.1, krr_alpha=0.7, kernel=linear, n_features=3
# --> Internal R2: 0.714, MAE: 0.485
#
# Testing: ridge_alpha=0.1, krr_alpha=0.7, kernel=polynomial, n_features=3
# --> Internal R2: 0.777, MAE: 0.282
#
# Testing: ridge_alpha=0.1, krr_alpha=0.7, kernel=rbf, n_features=3
# --> Internal R2: 0.764, MAE: 0.336
#
# Testing: ridge_alpha=0.1, krr_alpha=1.0, kernel=linear, n_features=3
# --> Internal R2: 0.714, MAE: 0.484
#
# Testing: ridge_alpha=0.1, krr_alpha=1.0, kernel=polynomial, n_features=3
# --> Internal R2: 0.776, MAE: 0.284
#
# Testing: ridge_alpha=0.1, krr_alpha=1.0, kernel=rbf, n_features=3
# --> Internal R2: 0.764, MAE: 0.350
#
# Testing: ridge_alpha=0.1, krr_alpha=2.0, kernel=linear, n_features=3
# --> Internal R2: 0.713, MAE: 0.482
#
# Testing: ridge_alpha=0.1, krr_alpha=2.0, kernel=polynomial, n_features=3
# --> Internal R2: 0.773, MAE: 0.300
#
# Testing: ridge_alpha=0.1, krr_alpha=2.0, kernel=rbf, n_features=3
# --> Internal R2: 0.764, MAE: 0.381
# Selected feature names: ['HOMO_min', 'η_max', 'Buried_Sterimol_B5_N1_Ni_5.0(Å)_min', '%Vbur_Ni_octant_–,–,–_Boltz']
#
# Testing: ridge_alpha=0.1, krr_alpha=0.7, kernel=linear, n_features=4
# --> Internal R2: 0.781, MAE: 0.369
#
# Testing: ridge_alpha=0.1, krr_alpha=0.7, kernel=polynomial, n_features=4
# --> Internal R2: 0.823, MAE: 0.270
#
# Testing: ridge_alpha=0.1, krr_alpha=0.7, kernel=rbf, n_features=4
# --> Internal R2: 0.791, MAE: 0.329
#
# Testing: ridge_alpha=0.1, krr_alpha=1.0, kernel=linear, n_features=4
# --> Internal R2: 0.783, MAE: 0.372
#
# Testing: ridge_alpha=0.1, krr_alpha=1.0, kernel=polynomial, n_features=4
# --> Internal R2: 0.829, MAE: 0.266
#
# Testing: ridge_alpha=0.1, krr_alpha=1.0, kernel=rbf, n_features=4
# --> Internal R2: 0.792, MAE: 0.343
#
# Testing: ridge_alpha=0.1, krr_alpha=2.0, kernel=linear, n_features=4
# --> Internal R2: 0.788, MAE: 0.380
#
# Testing: ridge_alpha=0.1, krr_alpha=2.0, kernel=polynomial, n_features=4
# --> Internal R2: 0.840, MAE: 0.277
#
# Testing: ridge_alpha=0.1, krr_alpha=2.0, kernel=rbf, n_features=4
# --> Internal R2: 0.790, MAE: 0.378
# Selected feature names: ['HOMO_min', 'η_max', 'Sterimol_B1_C2_N2(Å)_morfeus_min', 'Buried_Sterimol_B5_N1_Ni_5.0(Å)_min', '%Vbur_Ni_octant_–,–,–_Boltz']
#
# Testing: ridge_alpha=0.1, krr_alpha=0.7, kernel=linear, n_features=5
# --> Internal R2: 0.847, MAE: 0.335
#
# Testing: ridge_alpha=0.1, krr_alpha=0.7, kernel=polynomial, n_features=5
# --> Internal R2: 0.857, MAE: 0.314
#
# Testing: ridge_alpha=0.1, krr_alpha=0.7, kernel=rbf, n_features=5
# --> Internal R2: 0.824, MAE: 0.344
#
# Testing: ridge_alpha=0.1, krr_alpha=1.0, kernel=linear, n_features=5
# --> Internal R2: 0.850, MAE: 0.338
#
# Testing: ridge_alpha=0.1, krr_alpha=1.0, kernel=polynomial, n_features=5
# --> Internal R2: 0.864, MAE: 0.316
#
# Testing: ridge_alpha=0.1, krr_alpha=1.0, kernel=rbf, n_features=5
# --> Internal R2: 0.823, MAE: 0.358
#
# Testing: ridge_alpha=0.1, krr_alpha=2.0, kernel=linear, n_features=5
# --> Internal R2: 0.857, MAE: 0.347
#
# Testing: ridge_alpha=0.1, krr_alpha=2.0, kernel=polynomial, n_features=5
# --> Internal R2: 0.879, MAE: 0.322
#
# Testing: ridge_alpha=0.1, krr_alpha=2.0, kernel=rbf, n_features=5
# --> Internal R2: 0.819, MAE: 0.393
# Selected feature names: ['η_low_E', 'Sterimol_B1_Ni_N2(Å)_morfeus_max']
#
# Testing: ridge_alpha=0.3, krr_alpha=0.7, kernel=linear, n_features=2
# --> Internal R2: 0.682, MAE: 0.311
#
# Testing: ridge_alpha=0.3, krr_alpha=0.7, kernel=polynomial, n_features=2
# --> Internal R2: 0.649, MAE: 0.380
#
# Testing: ridge_alpha=0.3, krr_alpha=0.7, kernel=rbf, n_features=2
# --> Internal R2: 0.937, MAE: 0.293
#
# Testing: ridge_alpha=0.3, krr_alpha=1.0, kernel=linear, n_features=2
# --> Internal R2: 0.684, MAE: 0.311
#
# Testing: ridge_alpha=0.3, krr_alpha=1.0, kernel=polynomial, n_features=2
# --> Internal R2: 0.737, MAE: 0.345
#
# Testing: ridge_alpha=0.3, krr_alpha=1.0, kernel=rbf, n_features=2
# --> Internal R2: 0.938, MAE: 0.301
#
# Testing: ridge_alpha=0.3, krr_alpha=2.0, kernel=linear, n_features=2
# --> Internal R2: 0.688, MAE: 0.312
#
# Testing: ridge_alpha=0.3, krr_alpha=2.0, kernel=polynomial, n_features=2
# --> Internal R2: 0.853, MAE: 0.316
#
# Testing: ridge_alpha=0.3, krr_alpha=2.0, kernel=rbf, n_features=2
# --> Internal R2: 0.944, MAE: 0.335
# Selected feature names: ['η_low_E', 'Sterimol_B1_Ni_N2(Å)_morfeus_max', 'Buried_Sterimol_B5_N1_Ni_5.0(Å)_min']
#
# Testing: ridge_alpha=0.3, krr_alpha=0.7, kernel=linear, n_features=3
# --> Internal R2: 0.878, MAE: 0.332
#
# Testing: ridge_alpha=0.3, krr_alpha=0.7, kernel=polynomial, n_features=3
# --> Internal R2: 0.691, MAE: 0.315
#
# Testing: ridge_alpha=0.3, krr_alpha=0.7, kernel=rbf, n_features=3
# --> Internal R2: 0.875, MAE: 0.284
#
# Testing: ridge_alpha=0.3, krr_alpha=1.0, kernel=linear, n_features=3
# --> Internal R2: 0.879, MAE: 0.330
#
# Testing: ridge_alpha=0.3, krr_alpha=1.0, kernel=polynomial, n_features=3
# --> Internal R2: 0.719, MAE: 0.310
#
# Testing: ridge_alpha=0.3, krr_alpha=1.0, kernel=rbf, n_features=3
# --> Internal R2: 0.885, MAE: 0.301
#
# Testing: ridge_alpha=0.3, krr_alpha=2.0, kernel=linear, n_features=3
# --> Internal R2: 0.879, MAE: 0.325
#
# Testing: ridge_alpha=0.3, krr_alpha=2.0, kernel=polynomial, n_features=3
# --> Internal R2: 0.779, MAE: 0.302
#
# Testing: ridge_alpha=0.3, krr_alpha=2.0, kernel=rbf, n_features=3
# --> Internal R2: 0.898, MAE: 0.343
# Selected feature names: ['HOMO_Boltz', 'η_low_E', 'Sterimol_B1_Ni_N2(Å)_morfeus_max', 'Buried_Sterimol_B5_N1_Ni_5.0(Å)_min']
#
# Testing: ridge_alpha=0.3, krr_alpha=0.7, kernel=linear, n_features=4
# --> Internal R2: 0.768, MAE: 0.275
#
# Testing: ridge_alpha=0.3, krr_alpha=0.7, kernel=polynomial, n_features=4
# --> Internal R2: 0.874, MAE: 0.236
#
# Testing: ridge_alpha=0.3, krr_alpha=0.7, kernel=rbf, n_features=4
# --> Internal R2: 0.816, MAE: 0.330
#
# Testing: ridge_alpha=0.3, krr_alpha=1.0, kernel=linear, n_features=4
# --> Internal R2: 0.770, MAE: 0.273
#
# Testing: ridge_alpha=0.3, krr_alpha=1.0, kernel=polynomial, n_features=4
# --> Internal R2: 0.876, MAE: 0.242
#
# Testing: ridge_alpha=0.3, krr_alpha=1.0, kernel=rbf, n_features=4
# --> Internal R2: 0.821, MAE: 0.347
#
# Testing: ridge_alpha=0.3, krr_alpha=2.0, kernel=linear, n_features=4
# --> Internal R2: 0.777, MAE: 0.276
#
# Testing: ridge_alpha=0.3, krr_alpha=2.0, kernel=polynomial, n_features=4
# --> Internal R2: 0.881, MAE: 0.256
#
# Testing: ridge_alpha=0.3, krr_alpha=2.0, kernel=rbf, n_features=4
# --> Internal R2: 0.827, MAE: 0.387
# Selected feature names: ['HOMO_Boltz', 'η_low_E', 'Sterimol_B1_Ni_N2(Å)_morfeus_max', 'Buried_Sterimol_B5_N1_Ni_5.0(Å)_min', '%Vbur_Ni_octant_–,–,–_Boltz']
#
# Testing: ridge_alpha=0.3, krr_alpha=0.7, kernel=linear, n_features=5
# --> Internal R2: 0.857, MAE: 0.292
#
# Testing: ridge_alpha=0.3, krr_alpha=0.7, kernel=polynomial, n_features=5
# --> Internal R2: 0.819, MAE: 0.279
#
# Testing: ridge_alpha=0.3, krr_alpha=0.7, kernel=rbf, n_features=5
# --> Internal R2: 0.776, MAE: 0.342
#
# Testing: ridge_alpha=0.3, krr_alpha=1.0, kernel=linear, n_features=5
# --> Internal R2: 0.862, MAE: 0.295
#
# Testing: ridge_alpha=0.3, krr_alpha=1.0, kernel=polynomial, n_features=5
# --> Internal R2: 0.831, MAE: 0.279
#
# Testing: ridge_alpha=0.3, krr_alpha=1.0, kernel=rbf, n_features=5
# --> Internal R2: 0.782, MAE: 0.357
#
# Testing: ridge_alpha=0.3, krr_alpha=2.0, kernel=linear, n_features=5
# --> Internal R2: 0.876, MAE: 0.302
#
# Testing: ridge_alpha=0.3, krr_alpha=2.0, kernel=polynomial, n_features=5
# --> Internal R2: 0.852, MAE: 0.286
#
# Testing: ridge_alpha=0.3, krr_alpha=2.0, kernel=rbf, n_features=5
# --> Internal R2: 0.791, MAE: 0.392
# Selected feature names: ['Sterimol_B1_N2_Ni(Å)_morfeus_low_E', 'Sterimol_B1_Ni_N2(Å)_morfeus_low_E']
#
# Testing: ridge_alpha=1.0, krr_alpha=0.7, kernel=linear, n_features=2
# --> Internal R2: 0.713, MAE: 0.379
#
# Testing: ridge_alpha=1.0, krr_alpha=0.7, kernel=polynomial, n_features=2
# --> Internal R2: 0.726, MAE: 0.362
#
# Testing: ridge_alpha=1.0, krr_alpha=0.7, kernel=rbf, n_features=2
# --> Internal R2: 0.735, MAE: 0.360
#
# Testing: ridge_alpha=1.0, krr_alpha=1.0, kernel=linear, n_features=2
# --> Internal R2: 0.713, MAE: 0.380
#
# Testing: ridge_alpha=1.0, krr_alpha=1.0, kernel=polynomial, n_features=2
# --> Internal R2: 0.726, MAE: 0.361
#
# Testing: ridge_alpha=1.0, krr_alpha=1.0, kernel=rbf, n_features=2
# --> Internal R2: 0.735, MAE: 0.360
#
# Testing: ridge_alpha=1.0, krr_alpha=2.0, kernel=linear, n_features=2
# --> Internal R2: 0.713, MAE: 0.381
#
# Testing: ridge_alpha=1.0, krr_alpha=2.0, kernel=polynomial, n_features=2
# --> Internal R2: 0.729, MAE: 0.359
#
# Testing: ridge_alpha=1.0, krr_alpha=2.0, kernel=rbf, n_features=2
# --> Internal R2: 0.733, MAE: 0.363
# Selected feature names: ['Sterimol_B1_N2_Ni(Å)_morfeus_low_E', 'Sterimol_B1_Ni_N2(Å)_morfeus_low_E', '%Vbur_Ni_octant_+,–,+_low_E']
#
# Testing: ridge_alpha=1.0, krr_alpha=0.7, kernel=linear, n_features=3
# --> Internal R2: 0.845, MAE: 0.318
#
# Testing: ridge_alpha=1.0, krr_alpha=0.7, kernel=polynomial, n_features=3
# --> Internal R2: 0.824, MAE: 0.391
#
# Testing: ridge_alpha=1.0, krr_alpha=0.7, kernel=rbf, n_features=3
# --> Internal R2: 0.879, MAE: 0.338
#
# Testing: ridge_alpha=1.0, krr_alpha=1.0, kernel=linear, n_features=3
# --> Internal R2: 0.846, MAE: 0.320
#
# Testing: ridge_alpha=1.0, krr_alpha=1.0, kernel=polynomial, n_features=3
# --> Internal R2: 0.833, MAE: 0.386
#
# Testing: ridge_alpha=1.0, krr_alpha=1.0, kernel=rbf, n_features=3
# --> Internal R2: 0.877, MAE: 0.349
#
# Testing: ridge_alpha=1.0, krr_alpha=2.0, kernel=linear, n_features=3
# --> Internal R2: 0.849, MAE: 0.324
#
# Testing: ridge_alpha=1.0, krr_alpha=2.0, kernel=polynomial, n_features=3
# --> Internal R2: 0.848, MAE: 0.377
#
# Testing: ridge_alpha=1.0, krr_alpha=2.0, kernel=rbf, n_features=3
# --> Internal R2: 0.867, MAE: 0.376
# Selected feature names: ['distance_N2_C2(Å)_low_E', 'Sterimol_B1_N2_Ni(Å)_morfeus_low_E', 'Sterimol_B1_Ni_N2(Å)_morfeus_low_E', '%Vbur_Ni_octant_+,–,+_low_E']
#
# Testing: ridge_alpha=1.0, krr_alpha=0.7, kernel=linear, n_features=4
# --> Internal R2: 0.848, MAE: 0.304
#
# Testing: ridge_alpha=1.0, krr_alpha=0.7, kernel=polynomial, n_features=4
# --> Internal R2: 0.846, MAE: 0.377
#
# Testing: ridge_alpha=1.0, krr_alpha=0.7, kernel=rbf, n_features=4
# --> Internal R2: 0.841, MAE: 0.376
#
# Testing: ridge_alpha=1.0, krr_alpha=1.0, kernel=linear, n_features=4
# --> Internal R2: 0.848, MAE: 0.305
#
# Testing: ridge_alpha=1.0, krr_alpha=1.0, kernel=polynomial, n_features=4
# --> Internal R2: 0.858, MAE: 0.364
#
# Testing: ridge_alpha=1.0, krr_alpha=1.0, kernel=rbf, n_features=4
# --> Internal R2: 0.840, MAE: 0.373
#
# Testing: ridge_alpha=1.0, krr_alpha=2.0, kernel=linear, n_features=4
# --> Internal R2: 0.849, MAE: 0.310
#
# Testing: ridge_alpha=1.0, krr_alpha=2.0, kernel=polynomial, n_features=4
# --> Internal R2: 0.875, MAE: 0.354
#
# Testing: ridge_alpha=1.0, krr_alpha=2.0, kernel=rbf, n_features=4
# --> Internal R2: 0.838, MAE: 0.382
# Selected feature names: ['distance_N2_C2(Å)_low_E', 'Sterimol_B1_N2_Ni(Å)_morfeus_low_E', 'Sterimol_B1_Ni_N2(Å)_morfeus_low_E', 'Buried_Sterimol_B5_N1_Ni_5.0(Å)_max', '%Vbur_Ni_octant_+,–,+_low_E']
#
# Testing: ridge_alpha=1.0, krr_alpha=0.7, kernel=linear, n_features=5
# --> Internal R2: 0.877, MAE: 0.263
#
# Testing: ridge_alpha=1.0, krr_alpha=0.7, kernel=polynomial, n_features=5
# --> Internal R2: 0.888, MAE: 0.369
#
# Testing: ridge_alpha=1.0, krr_alpha=0.7, kernel=rbf, n_features=5
# --> Internal R2: 0.868, MAE: 0.376
#
# Testing: ridge_alpha=1.0, krr_alpha=1.0, kernel=linear, n_features=5
# --> Internal R2: 0.877, MAE: 0.264
#
# Testing: ridge_alpha=1.0, krr_alpha=1.0, kernel=polynomial, n_features=5
# --> Internal R2: 0.889, MAE: 0.368
#
# Testing: ridge_alpha=1.0, krr_alpha=1.0, kernel=rbf, n_features=5
# --> Internal R2: 0.871, MAE: 0.374
#
# Testing: ridge_alpha=1.0, krr_alpha=2.0, kernel=linear, n_features=5
# --> Internal R2: 0.878, MAE: 0.267
#
# Testing: ridge_alpha=1.0, krr_alpha=2.0, kernel=polynomial, n_features=5
# --> Internal R2: 0.892, MAE: 0.363
#
# Testing: ridge_alpha=1.0, krr_alpha=2.0, kernel=rbf, n_features=5
# --> Internal R2: 0.874, MAE: 0.382
#
# Best Model by Internal Test R2
# {'ridge_alpha': 0.3, 'krr_alpha': 2.0, 'kernel': 'rbf', 'n_features': 2}
# R2: 0.944
# Selected Features: ['η_low_E', 'Sterimol_B1_Ni_N2(Å)_morfeus_max']
#
# Best Model by Internal Test MAE
# {'ridge_alpha': 0.3, 'krr_alpha': 0.7, 'kernel': 'polynomial', 'n_features': 4}
# MAE: 0.236
# Selected Features: ['HOMO_Boltz', 'η_low_E', 'Sterimol_B1_Ni_N2(Å)_morfeus_max', 'Buried_Sterimol_B5_N1_Ni_5.0(Å)_min']

# %% [markdown]
# #### Try One Model

# %% [markdown]
# ##### CV To Select Optimal Number of Features for You

# %%
X_train_selected, X_internal_test_selected, X_external_test_selected, selected_features = hp.feature_selection(
    selection_method='rfe_cv',   # or 'rfe_cv'
    X_train=X_train,
    y_train=y_train,
    alpha=0.3,
    min_features=2,
    scoring = 'neg_mean_squared_error',
    X_internal_test=X_internal_test,
    X_external_test=X_external_test
)
# Out:
# Optimal number of features: 8
# Selected feature names: ['HOMO_Boltz', 'HOMO_max', 'η_max', 'η_low_E', 'Sterimol_B1_C2_N2(Å)_morfeus_min', 'Sterimol_B1_Ni_N2(Å)_morfeus_max', 'Buried_Sterimol_B5_N1_Ni_5.0(Å)_min', '%Vbur_Ni_octant_–,–,–_Boltz']

# %% [markdown]
# ##### Select Optimal Number of Features for RFE yourself

# %%
X_train_selected, X_internal_test_selected, X_external_test_selected, selected_fearures = hp.feature_selection(
    selection_method='rfe', 
    X_train=X_train,
    y_train=y_train,
    alpha=0.3,
    n_features = 4,
    X_internal_test=X_internal_test,
    X_external_test=X_external_test
)
# Out:
# Selected feature names: ['HOMO_Boltz', 'η_low_E', 'Sterimol_B1_Ni_N2(Å)_morfeus_max', 'Buried_Sterimol_B5_N1_Ni_5.0(Å)_min']

# %% [markdown]
# ##### Try KRR Modeling

# %%
krr_results = hp.regression('krr', X_train_selected, y_train, y_train_labels,
               alpha = 0.7,
               kernel='polynomial',
               X_internal_test=X_internal_test_selected, y_internal_test=y_internal_test, 
               y_internal_test_labels=y_internal_test_labels,
               X_external_test=X_external_test_selected, y_external_test=y_external_test,
               y_external_test_labels=y_external_test_labels)

fig, ax = plt.subplots(figsize=(6, 6))
ax.set_xlabel('Experimental $ΔΔG^{‡}$', fontsize=16)
ax.set_ylabel('Predicted $ΔΔG^{‡}$ (kcal/mol)', fontsize=16)
subset_train = krr_results[krr_results['set'] == 'train']
ax.scatter(subset_train['true_value'], subset_train['predicted_value_krr'], color='black', label='Train', alpha=0.7)
subset_internal_test = krr_results[krr_results['set'] == 'internal_test']
ax.scatter(subset_internal_test['true_value'], subset_internal_test['predicted_value_krr'], color='blue', label='Internal Test', alpha=0.7)
# subset_external_test = krr_results[krr_results['set'] == 'external_test']
# ax.scatter(subset_external_test['true_value'], subset_external_test['predicted_value_krr'], color='green', label='External Test', alpha=0.7)
ax.legend()
